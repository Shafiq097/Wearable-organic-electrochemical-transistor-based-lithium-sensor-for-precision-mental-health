# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame, Panel
pd.set_option('display.max_rows',15) # this limit maximum numbers of rows
# import libs
import matplotlib
import os.path
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as ticker
from matplotlib import rcParams
from matplotlib import rc
import matplotlib.gridspec as gridspec
matplotlib.font_manager._rebuild()
import matplotlib.ticker as ticker
from scipy.optimize import curve_fit
import scipy
import scipy.optimize
rc('font',**{'family':'sans-serif','sans-serif':['PT Sans'],'size': 55})
colors = ['#4E79A7', '#F28E2B', '#E15759', '#59A14E', '#EDC949', '#AF7AA1', '#FF9DA7', '#9C755F', '#BAB0AC', '#76B7B2']
# Out:
# C:\Users\Shafiq\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# open file
data_SF1 = pd.read_excel('Supplementary Figure S1.xlsx', skiprows=2, engine='openpyxl')

# %%
#Au

fig1, ax = plt.subplots(1, figsize=(7,5))

plt.plot(data_SF1.iloc[:,0],data_SF1.iloc[:,1],linewidth=2, color=colors[0], alpha = 1,label='n1')
    


plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=16)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=True, left=False)


font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 20,
}

plt.xlabel(r'Length $(\mu m)$',fontdict=font_style)
plt.ylabel(r'Thickness (nm)', fontdict=font_style)
# Out:
# Text(0, 0.5, 'Thickness (nm)')

# %%
#PEDOT:PSS
fig1, ax = plt.subplots(1, figsize=(7,5))

plt.plot(data_SF1.iloc[:,2],data_SF1.iloc[:,3],linewidth=2, color=colors[0], alpha = 1,label='n1')
    

plt.tick_params(direction='in', right=True, top=True)
plt.tick_params(labelsize=14)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=True, left=True)


plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=16)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=True, left=False)


font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 20,
}

plt.xlabel(r'Length $(\mu m)$',fontdict=font_style)
plt.ylabel(r'Thickness (nm)', fontdict=font_style)
# Out:
# Text(0, 0.5, 'Thickness (nm)')

# %%
#Dielectric
fig1, ax = plt.subplots(1, figsize=(7,5))

plt.plot(data_SF1.iloc[:,4],data_SF1.iloc[:,5],linewidth=2, color=colors[0], alpha = 1,label='n1')
    



plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=16)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=True, left=False)


font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 20,
}

plt.xlabel(r'Length $(\mu m)$',fontdict=font_style)
plt.ylabel(r'Thickness (nm)', fontdict=font_style)
# Out:
# Text(0, 0.5, 'Thickness (nm)')

# %%
#Ag/AgCl

fig1, ax = plt.subplots(1, figsize=(7,5))

plt.plot(data_SF1.iloc[:,6],data_SF1.iloc[:,7],linewidth=2, color=colors[0], alpha = 1,label='n1')
    

plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=16)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=True, left=False)


font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 20,
}

plt.xlabel(r'Length $(\mu m)$',fontdict=font_style)
plt.ylabel(r'Thickness (nm)', fontdict=font_style)
# Out:
# Text(0, 0.5, 'Thickness (nm)')

# %%
#ISM

fig1, ax = plt.subplots(1, figsize=(7,5))

plt.plot(data_SF1.iloc[:,8],data_SF1.iloc[:,9],linewidth=2, color=colors[0], alpha = 1,label='n1')
    
plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=16)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=True, left=False)


font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 20,
}

plt.xlabel(r'Length $(\mu m)$',fontdict=font_style)
plt.ylabel(r'Thickness (nm)', fontdict=font_style)
# Out:
# Text(0, 0.5, 'Thickness (nm)')

# %%
# open file
data_sf3a = pd.read_excel('Supplementary Figure S3.xlsx', sheet_name='S3A', skip_row=1,engine='openpyxl')
data_sf3b = pd.read_excel('Supplementary Figure S3.xlsx', sheet_name='S3B', skip_row=1,engine='openpyxl')

# %%
fig1, ax1 = plt.subplots(1, figsize=(5,5))
ax2 = ax1.twinx()

ax1.plot(data_sf3a.iloc[:,0],data_sf3a.iloc[:,1],linewidth=2, color='k',alpha = 0.8,label='n1',marker='o')  
ax2.plot(data_sf3a.iloc[:,0],data_sf3a.iloc[:,2],linewidth=2,color=colors[1],alpha = 0.8,marker='o')


ax1.tick_params(labelsize=16)

ax2.tick_params(color=colors[2],labelsize=16)

ax2.set_ylim([0.2,1])
ax1.set_ylim([-2,.01])

plt.xlim([-0.11,.811])

ax2.set_yticks([0.2,.4,0.6,.8,1])

ax2.tick_params(axis='y', colors=colors[1])
ax2.spines['right'].set_color(colors[1]) 

ax1.set_xlabel(r'$V_{GS}$ (V)', fontsize=18)
ax1.set_ylabel(r'$I_{DS}$ ( mA)',color='k', fontsize=18)
ax2.set_ylabel(r'$I_{GS}\; ( \mu A)$',color=colors[1], fontsize=18)

plt.axvspan(.000, .5, alpha=0.10,color=colors[1])

# %%
fig1, ax1 = plt.subplots(1, figsize=(5,5))
ax2 = ax1.twinx()


ax1.plot(data_sf3b.iloc[:,0],data_sf3b.iloc[:,1],linewidth=2, color='k',alpha = 0.8,label='n1',marker='o')  
ax2.plot(data_sf3b.iloc[:,0],data_sf3b.iloc[:,2],linewidth=2,color=colors[1],alpha = 0.8,marker='o')

ax1.tick_params(labelsize=16)

ax2.tick_params(color=colors[2],labelsize=16)

ax2.set_ylim([0.2,1])
ax1.set_ylim([-1.2,.01])

plt.xlim([-0.11,.811])

ax2.set_yticks([0.2,.4,0.6,.8,1])

ax2.tick_params(axis='y', colors=colors[1])
ax2.spines['right'].set_color(colors[1]) 

ax1.set_xlabel(r'$V_{GS}$ (V)', fontsize=18)
ax1.set_ylabel(r'$I_{DS}$ ( mA)',color='k', fontsize=18)
ax2.set_ylabel(r'$I_{GS} \; ( \mu A)$',color=colors[1], fontsize=18)

plt.axvspan(.000, .2, alpha=0.10,color=colors[1])

# %%
# open file
data_sf4a = pd.read_excel('Supplementary Figure S4.xlsx', sheet_name='S4A', skiprows=2,engine='openpyxl')
data_sf4b = pd.read_excel('Supplementary Figure S4.xlsx', sheet_name='S4B', skiprows=2,engine='openpyxl')
data_sf4c = pd.read_excel('Supplementary Figure S4.xlsx', sheet_name='S4C', skip_row=1,engine='openpyxl')

# %%
fig1, ax = plt.subplots(1, figsize=(5,5))

plt.plot(data_sf4a.iloc[:,0],data_sf4a.iloc[:,1],linewidth=2, color=colors[0], alpha = 0.8,label='n1')
plt.plot(data_sf4a.iloc[:,2],data_sf4a.iloc[:,3],linewidth=2, color=colors[1], alpha = 0.8,label='n1')
plt.plot(data_sf4a.iloc[:,4],data_sf4a.iloc[:,5],linewidth=2, color=colors[2], alpha = 0.8,label='n1')
plt.plot(data_sf4a.iloc[:,6],data_sf4a.iloc[:,7],linewidth=2, color=colors[3], alpha = 0.8,label='n1')
plt.plot(data_sf4a.iloc[:,8],data_sf4a.iloc[:,9],linewidth=2, color=colors[4], alpha = 0.8,label='n1')


font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 20,
}
plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=16)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=True, left=False)

plt.axvspan(0, 120, alpha=0.05,color='coral')
plt.axvspan(120, 240, alpha=0.05,color='springgreen')


plt.xlim([0,240])

ax.set_xticks([0,40,80,120, 160, 200, 240])

plt.xlabel('Time (s) ' ,fontdict=font_style)
plt.ylabel(r'$ I_{ds}$ (mA)', fontdict=font_style)
# Out:
# Text(0, 0.5, '$ I_{ds}$ (mA)')

# %%
fig1, ax = plt.subplots(1, figsize=(5,5))

plt.plot((data_sf4b.iloc[:,0]),-data_sf4b.iloc[:,1],linewidth=2, color=colors[0], alpha = 0.8,label='n1')
plt.plot((data_sf4b.iloc[:,2]),-data_sf4b.iloc[:,3],linewidth=2, color=colors[1], alpha = 0.8,label='n1')
plt.plot((data_sf4b.iloc[:,4]),-data_sf4b.iloc[:,5],linewidth=2, color=colors[2], alpha = 0.8,label='n1')
plt.plot((data_sf4b.iloc[:,6]),-data_sf4b.iloc[:,7],linewidth=2, color=colors[3], alpha = 0.8,label='n1')
plt.plot((data_sf4b.iloc[:,8]),-data_sf4b.iloc[:,9],linewidth=2.8, color=colors[4], alpha = 0.8,label='n1')



font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 20,
}
plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=16)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=True, left=False)


plt.xlim([120,240])

ax.set_xticks([120, 160, 200, 240])

plt.xlabel('Time (s) ' ,fontdict=font_style)
plt.ylabel(r'$|\Delta I_{ds}/I_0$|', fontdict=font_style)
# Out:
# Text(0, 0.5, '$|\\Delta I_{ds}/I_0$|')

# %%
r_I=[np.mean(data_sf4b.iloc[19000:19998,1]),np.mean(data_sf4b.iloc[19000:19998,3]),np.mean(data_sf4b.iloc[19000:19998,5]), np.mean(data_sf4b.iloc[19000:19998,7]), np.mean(data_sf4b.iloc[19000:19998,9])]
r_I_avg=np.mean(r_I)
con_avg=[1]

#standard deviation
rI_sd=np.zeros(len(r_I))

s=0
for i in range(len(r_I)):
    s=s+(r_I[i]-r_I_avg)**2
    
rI_sd=(s/(5))**0.5

# %%
fig1, ax = plt.subplots(1, figsize=(5,5))

plt.plot(data_sf4c.iloc[:,0],data_sf4c.iloc[:,1],linewidth=2,linestyle='dashed', color='red', alpha = 1,label='n1')
plt.errorbar(con_avg, np.abs(r_I_avg), yerr=rI_sd, fmt='o', alpha = .5, markersize=12,solid_capstyle='projecting', capsize=2,color='black')

font_style = {
    'family': 'PT sans',
    'color': 'black',
    'size': 20,
}

plt.xscale('log')
plt.xlabel('Concentration (mM) ' ,fontdict=font_style)
plt.ylabel(r'$|\Delta$ $I_{ds}/I_0|$', fontdict=font_style)


plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=16)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=True, left=False)
plt.minorticks_on()


ax.set_yticks([0.05,.15,.25,.35])
ax.set_xticks([0.01,.1,1, 10])

# %%
# open file
data_sf5a = pd.read_excel('Supplementary Figure S5.xlsx', sheet_name='S5A', skiprows=2,engine='openpyxl')
data_sf5b = pd.read_excel('Supplementary Figure S5.xlsx', sheet_name='S5B', skiprows=2,engine='openpyxl')
data_sf5c = pd.read_excel('Supplementary Figure S5.xlsx', sheet_name='S5C', skiprows=2,engine='openpyxl')
data_sf5d = pd.read_excel('Supplementary Figure S5.xlsx', sheet_name='S5D', skiprows=2,engine='openpyxl')

# %%
fig1, ax = plt.subplots(1, figsize=(5,5))

plt.plot(data_sf5a.iloc[:,0],data_sf5a.iloc[:,1],linewidth=2, color='crimson', linestyle='dashed',alpha = 0.8,label='n1')
plt.plot(data_sf5a.iloc[:,2],data_sf5a.iloc[:,3],linewidth=2, color='crimson', linestyle='dotted',alpha = 0.8,label='n1')
plt.plot(data_sf5a.iloc[:,4],data_sf5a.iloc[:,5],linewidth=2, color='crimson', alpha = 0.8,label='n1')
font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 24,
}

plt.xlabel('Time (s) ' ,fontdict=font_style)
plt.ylabel(r'$|\Delta$ $I_{ds}| (\mu A)$', fontdict=font_style)

plt.xlim([120,240])
plt.xticks([120,160,200,240])
plt.legend([r'0.1mM',r'1mM',r'10mM'], fontsize=22,loc='lower right',frameon=False)
plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=22)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=True, left=True)
ax.tick_params(axis='x', pad=9)
ax.tick_params(axis='y', pad=9)

# %%
fig1, ax = plt.subplots(1, figsize=(5,5))

plt.plot(data_sf5b.iloc[:,0],data_sf5b.iloc[:,1],linewidth=2, color='darkorange',linestyle='dashed', alpha = 0.8,label='n1')
plt.plot(data_sf5b.iloc[:,2],data_sf5b.iloc[:,3],linewidth=2, color='darkorange', linestyle='dotted',alpha = 0.8,label='n1')
plt.plot(data_sf5b.iloc[:,4],data_sf5b.iloc[:,5],linewidth=2, color='darkorange', alpha = 0.8,label='n1')
font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 24,
}

plt.xlabel('Time (s) ' ,fontdict=font_style)
plt.ylabel(r'$|\Delta$ $I_{ds}| (\mu A)$', fontdict=font_style)
plt.legend([r'0.1mM',r'1mM',r'10mM'], fontsize=22,loc='lower right',frameon=False)

plt.xlim([120,240])
plt.xticks([120,160,200,240])

plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=22)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=True, left=True)
ax.tick_params(axis='x', pad=9)
ax.tick_params(axis='y', pad=9)

# %%
fig1, ax = plt.subplots(1, figsize=(5,5))

plt.plot(data_sf5c.iloc[:,0],data_sf5c.iloc[:,1],linewidth=2, color='forestgreen', linestyle='dashed', alpha = 0.8,label='n1')
plt.plot(data_sf5c.iloc[:,2],data_sf5c.iloc[:,3],linewidth=2, color='forestgreen',  linestyle='dotted',alpha = 0.8,label='n1')
plt.plot(data_sf5c.iloc[:,4],data_sf5c.iloc[:,5],linewidth=2, color='forestgreen', alpha = 0.8,label='n1')
font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 24,
}

plt.xlabel('Time (s) ' ,fontdict=font_style)
plt.ylabel(r'$|\Delta$ $I_{ds}| (\mu A)$', fontdict=font_style)

plt.xlim([120,240])
plt.xticks([120,160,200,240])
plt.legend([r'0.1mM',r'1mM',r'10mM'], fontsize=22,loc='lower right',frameon=False)
plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=22)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=True, left=True)
ax.tick_params(axis='x', pad=9)
ax.tick_params(axis='y', pad=9)

# %%
fig1, ax = plt.subplots(1, figsize=(5,5))

plt.plot(data_sf5d.iloc[:,0],data_sf5d.iloc[:,1],linewidth=2, color='darkred',linestyle='dashed', alpha = 0.8,label='n1')
plt.plot(data_sf5d.iloc[:,2],data_sf5d.iloc[:,3],linewidth=2, color='darkred', linestyle='dotted',alpha = 0.8,label='n1')
plt.plot(data_sf5d.iloc[:,4],data_sf5d.iloc[:,5],linewidth=2, color='darkred', alpha = 0.8,label='n1')
font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 24,
}

plt.xlabel('Time (s) ' ,fontdict=font_style)
plt.ylabel(r'$|\Delta$ $I_{ds}| (\mu A)$', fontdict=font_style)
plt.legend([r'0.1mM',r'1mM',r'10mM'], fontsize=22,loc='lower right',frameon=False)
plt.xlim([120,240])
plt.xticks([120,160,200,240])

plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=22)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=True, left=True)
ax.tick_params(axis='x', pad=9)
ax.tick_params(axis='y', pad=9)

# %%
# open file
data_sf6a = pd.read_excel('Supplementary Figure S6.xlsx', sheet_name='S6A', skip_row=1,engine='openpyxl')
data_sf6c = pd.read_excel('Supplementary Figure S6.xlsx', sheet_name='S6C', skip_row=1,engine='openpyxl')

# %%
fig1, ax = plt.subplots(1, figsize=(5,5))
plt.plot(data_sf6a.iloc[:,0],data_sf6a.iloc[:,1],linewidth=2, alpha = 0.8,label='n1',color='midnightblue') 

font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 24,
}
plt.xlabel('Time (s) ' ,fontdict=font_style)
plt.ylabel(r'$ |\Delta I_{ds}/I_0| $',fontdict=font_style)
plt.xlim([0,1020])
plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=22)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=False, left=False)
ax.tick_params(axis='x', pad=9)
ax.tick_params(axis='y', pad=9)

# %%
fig1, ax = plt.subplots(1, figsize=(5,5))
plt.plot(data_sf6c.iloc[:,0],data_sf6c.iloc[:,1],linewidth=1, linestyle='-',marker='o',alpha = 0.8,label='n1',color='midnightblue') 
plt.plot(data_sf6c.iloc[:,0],data_sf6c.iloc[:,2],linewidth=1, linestyle='-',marker='o',alpha = 0.5,label='n1',color='red')
font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 24,
}
plt.xlabel('Actual Concentration (mM) ' ,fontdict=font_style)
plt.ylabel('Measured Concentration (mM)',fontdict=font_style)
plt.legend(['LS-OECT','Commercial'],fontsize=22,frameon=False, loc='upper left')
plt.ylim([0,2.05])
plt.xlim([0,2.05])
plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=22)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=False, left=False)
ax.tick_params(axis='x', pad=9)
ax.tick_params(axis='y', pad=9)

# %%
# open file
data_sf7 = pd.read_excel('Supplementary Figure S7.xlsx', sheet_name='S7', skiprows=2,engine='openpyxl')

# %%
fig1, ax = plt.subplots(1, figsize=(5,5))

plt.plot(data_sf7.iloc[:,0],-data_sf7.iloc[:,1],linewidth=2, color=colors[9], alpha = 1,label='n1')
plt.plot(data_sf7.iloc[:,2],-data_sf7.iloc[:,3],linewidth=2, color=colors[9], alpha = 1,label='n1')
plt.plot(data_sf7.iloc[:,4],-data_sf7.iloc[:,5],linewidth=2, color=colors[9], alpha = 1,label='n1')
plt.plot(data_sf7.iloc[:,6],-data_sf7.iloc[:,7],linewidth=2, color=colors[9], alpha = 1,label='n1')
plt.plot(data_sf7.iloc[:,8],-data_sf7.iloc[:,9],linewidth=2, color=colors[9], alpha = 1,label='n1')
font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 24,
}

plt.xlabel('Time (s) ' ,fontdict=font_style)
plt.ylabel(r'$|\Delta$ $I_{ds}/I_0|$', fontdict=font_style)
plt.ylim([-0.005,.065])
plt.xlim([50,80])
plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=22)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=True, left=True)
ax.tick_params(axis='x', pad=9)
ax.tick_params(axis='y', pad=9)
