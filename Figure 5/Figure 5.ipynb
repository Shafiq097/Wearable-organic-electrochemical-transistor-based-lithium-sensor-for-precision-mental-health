# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame, Panel
pd.set_option('display.max_rows',15) # this limit maximum numbers of rows
# import libs
import matplotlib
import os.path
import matplotlib.pyplot as plt
import numpy as np
from numpy import savetxt
import matplotlib.ticker as ticker
from matplotlib import rcParams
from matplotlib import rc
import matplotlib.gridspec as gridspec
matplotlib.font_manager._rebuild()
import matplotlib.ticker as ticker
from scipy.optimize import curve_fit
import scipy
import scipy.optimize
rc('font',**{'family':'sans-serif','sans-serif':['PT Sans'],'size': 55})
colors = ['#4E79A7', '#F28E2B', '#E15759', '#59A14E', '#EDC949', '#AF7AA1', '#FF9DA7', '#9C755F', '#BAB0AC', '#76B7B2']
# Out:
# C:\Users\Shafiq\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# open file
data_5b = pd.read_excel('Figure_5B.xlsx', skip_row=1,engine='openpyxl')

# %%
fig, ax = plt.subplots(1, figsize=(5,5))


plt.plot(data_5b.iloc[:,0],data_5b.iloc[:,1],linewidth=2, color='brown', alpha = 0.8,label='n1')


font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 24,
}


plt.xlabel('Time (s)',fontdict=font_style)
plt.ylabel('Concentration (mM)', fontdict=font_style)
plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=22)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=False, left=False)
ax.tick_params(axis='x', pad=7)
ax.tick_params(axis='y', pad=7)
plt.xlim([0,700])
plt.ylim([0,.52])

plt.xlabel('Time (s)' ,fontdict=font_style)

plt.ylabel(r'$I_{iontophoresis}\; (mA cm^{-2})$', fontdict=font_style)
# Out:
# Text(0, 0.5, '$I_{iontophoresis}\\; (mA cm^{-2})$')

# %%
# open file
data_5f = pd.read_excel('Figure_5F.xlsx', skiprows=2,engine='openpyxl')

# %%
#Figure 5F
fig1, ax = plt.subplots(1, figsize=(5,5))


plt.plot(data_5f.iloc[:,0],data_5f.iloc[:,1],linewidth=2, color='olive',alpha =1,label='n1')
plt.plot(data_5f.iloc[:,2],data_5f.iloc[:,3],linewidth=2, color='darkolivegreen',alpha =1,label='n1')
plt.plot(data_5f.iloc[:,4],data_5f.iloc[:,5],linewidth=2, color='forestgreen',alpha =1,label='n1')


font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 24,
}


plt.xlabel('Time (s)',fontdict=font_style)
plt.ylabel('Concentration (mM)', fontdict=font_style)
plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=22)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=False, left=False)
ax.tick_params(axis='x', pad=7)
ax.tick_params(axis='y', pad=7)
plt.xlim([0,1200])
plt.ylim([0,2.5])
plt.legend(['Subject 1','Subject 2', 'Subject 3'],fontsize=18,frameon=False,loc='upper left')
ax.set_xticks([0, 300, 600, 900, 1200])
ax.set_yticks([0, 0.5, 1.0, 1.5, 2.0,2.5])

# %%
#Figure 5F inset
fig1, ax = plt.subplots(1, figsize=(2.5,2.5))


plt.plot(data_5f.iloc[:,0],data_5f.iloc[:,1],linewidth=2, color='olive',alpha =1,label='n1')
plt.plot(data_5f.iloc[:,2],data_5f.iloc[:,3],linewidth=2, color='darkolivegreen',alpha =1,label='n1')
plt.plot(data_5f.iloc[:,4],data_5f.iloc[:,5],linewidth=2, color='forestgreen',alpha =1,label='n1')

font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 20,
}


plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=18)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=False, left=False)
ax.tick_params(axis='x', pad=7)
ax.tick_params(axis='y', pad=7)
plt.xlim([300,600])
plt.ylim([0.08,.12])
ax.set_xticks([300, 600])

# %%
# open file
data_5g = pd.read_excel('Figure_5G.xlsx', skip_row=1,engine='openpyxl')

# %%
C_h_m_1=data_5g.iloc[0,0]
c_h_1c=data_5g.iloc[0,1]
C_h_m_2=data_5g.iloc[1,0]
c_h_2c=data_5g.iloc[1,1]
C_h_m_3=data_5g.iloc[2,0]
c_h_3c=data_5g.iloc[2,1]


import seaborn as sns

fig1, ax = plt.subplots(1, figsize=(5,5))


x=[1,2,3,4,5,6]

# set capsize param (this is a global setting, so only set it once)
#plt.rcParams['errorbar.capsize'] = 10

# create dataframe as shown by gepcel
X_val = ['Subject 1', 'Subject 2','Subject 3']

Con_s=[C_h_m_1,C_h_m_2,C_h_m_3]
Con_c=[c_h_1c,c_h_2c,c_h_3c]
#df = pd.DataFrame({'X_val':X_val,'Concentration':Con})

X_axis = np.arange(len(X_val)) 
  
plt.bar(X_axis - 0.2, Con_s, 0.4, label = 'WLS-OECT',color='darkorange',alpha=0.5) 
plt.bar(X_axis + 0.2, Con_c, 0.4, label = 'Commercial',color='firebrick',alpha=0.9)

plt.xticks(X_axis, X_val) 

font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 24,
}
plt.ylim([0,2.5])
ax.set_yticks([0, 0.5, 1.0, 1.5, 2.0,2.5])
#ax.set_yticks([0.5,1])
plt.legend(['WLS-OECT','Commercial'],fontsize=18,frameon=False,loc='upper left')
plt.ylabel('Concentration (mM) ' ,fontdict=font_style)
plt.xlabel(r'', fontdict=font_style)
plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=20)
ax.tick_params(axis='x',labelsize=20)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=True, left=True)

# %%
# open file
data_5h = pd.read_excel('Figure_5H.xlsx', skiprows=2, engine='openpyxl')

# %%
fig1, ax = plt.subplots(1, figsize=(5,5))


plt.plot(data_5h.iloc[:,0],data_5h.iloc[:,1],linewidth=2, color='darkred',alpha =1,label='n1')
plt.plot(data_5h.iloc[:,2],data_5h.iloc[:,3],linewidth=2, color='red',alpha =1,label='n1')
plt.plot(data_5h.iloc[:,4],data_5h.iloc[:,5],linewidth=2, color='orangered',alpha =1,label='n1')
font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 24,
}


plt.xlabel('Time (s)',fontdict=font_style)
plt.ylabel('Concentration (mM)', fontdict=font_style)
plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=22)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=False, left=False)
ax.tick_params(axis='x', pad=7)
ax.tick_params(axis='y', pad=7)
plt.xlim([0,1200])
plt.ylim([0,2.5])

plt.legend(['Subject 4','Subject 5', 'Subject 6'],fontsize=16,frameon=False,loc='upper right')

ax.set_xticks([0, 300, 600, 900, 1200])
ax.set_yticks([0, 0.5, 1.0, 1.5, 2.0,2.5])

# %%
# open file
data_5i = pd.read_excel('Figure_5I.xlsx', skip_row=1,engine='openpyxl')

# %%
C_p_m_1=data_5i.iloc[0,0]
c_p_1c=data_5i.iloc[0,1]
C_p_m_2=data_5i.iloc[1,0]
c_p_2c=data_5i.iloc[1,1]
C_p_m_3=data_5i.iloc[2,0]
c_p_3c=data_5i.iloc[2,1]
import seaborn as sns

fig1, ax = plt.subplots(1, figsize=(5,5))



# set capsize param (this is a global setting, so only set it once)
#plt.rcParams['errorbar.capsize'] = 10

# create dataframe as shown by gepcel
X_val = ['Subject 4', 'Subject 5','Subject 6']

Con_s=[C_p_m_1,C_p_m_2,C_p_m_3]
Con_c=[c_p_1c,c_p_2c,c_p_3c]
#df = pd.DataFrame({'X_val':X_val,'Concentration':Con})

X_axis = np.arange(len(X_val)) 
  
plt.bar(X_axis - 0.2, Con_s, 0.4, label = 'WLS-OECT',color='darkorange',alpha=0.5) 
plt.bar(X_axis + 0.2, Con_c, 0.4, label = 'Commercial',color='firebrick',alpha=0.9)

plt.xticks(X_axis, X_val) 

font_style = {
    'family': 'PT sans',
    'color': 'black',
#    'weight': 'bold',
    'size': 24,
}
plt.ylim([0,2.5])
ax.set_yticks([0, 0.5, 1.0, 1.5, 2.0,2.5])
#ax.set_yticks([0.5,1])
plt.legend(['WLS-OECT','Commercial'],fontsize=18,frameon=False,loc='upper left')
plt.ylabel('Concentration (mM) ' ,fontdict=font_style)
plt.xlabel(r'', fontdict=font_style)
plt.tick_params(direction='in', right=False, top=False)
plt.tick_params(labelsize=20)
ax.tick_params(axis='x',labelsize=20)
plt.tick_params(direction='in', which='major', length=5, bottom=True, left=True)
plt.tick_params(direction='in', which='minor', length=2, bottom=True, left=True)
